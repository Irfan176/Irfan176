# %% [markdown]
# <a href="https://colab.research.google.com/github/Irfan176/Irfan176/blob/main/Experiment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## SE ELEC
# ## Irfan Sheikh
# ## Roll No. 16

# %% [markdown]
# ### AIM: To implement a python program for the following:
# ### a) Read an existing .csv file
# ### b) Create a dataframe using .csv file and display the frame.
# ### c) Visualize the dataframe using Bar chart,Histogram,Pie chart,Line Graph.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Python Class notes (College)/Data Class SFIT/exp8_data - exp8_data.csv")
df
# Out:
#    RollNo    Name     PID
# 0       1   irfan  894534
# 1       2     raj  567843
# 2       3  adarsh  896523
# 3       4   divya  563490
# 4       5   jyoti  895312
# 5       6  satbir  786521

# %% [markdown]
# more than one sheet ('','name of sheet')

# %%
df1=pd.read_excel("/content/drive/MyDrive/Python Class notes (College)/Data Class SFIT/Data.xlsx")
df1
# Out:
#    Roll. No    Name     PID
# 0         1  irfan   894534
# 1         2     raj  567843
# 2         3  adarsh  896523
# 3         4   divya  563490
# 4         5   jyoti  895312
# 5         6  satbir  786521

# %%
import matplotlib.pyplot as plt

# %%
empdata={"EmployeeID":[101,102,103,104,105],"EmployeeName":['Divya','Satbir','Jyoti','Raj','Irfan'],"Salary":[25000,30000,35000,40000,45000]}
df5=pd.DataFrame(empdata)
x=df5["EmployeeID"]
y=df5["Salary"]
plt.bar(x,y,label="Employee Salaries",color='green')
plt.xlabel("Emp ID")
plt.ylabel("Sal")
plt.title("St.Francis Institute of Technology")
plt.show()

# %%
plt.hist(df4['pid'])
plt.show()

# %% [markdown]
# # To plot Pie Chart

# %%
slices=[25,20,15,15,25]
depts=['INFT','CMPN','EXTC','MECH','ELEC']
color=['cyan','red','blue','gold','brown']
plt.pie(slices,labels=depts,colors=color,autopct="%.1f%%",startangle=90,shadow=True)
plt.show()

# %% [markdown]
# # To plot line graph

# %%
x=[25,20,15,15,25]
y=['INFT','CMPN','EXTC','MECH','ELEC']
plt.plot(x,y,'red')

# %% [markdown]
# # 7.B Post lab Programs

# %% [markdown]
# ### 1. Write a Python program to create Data Frame using Dictionary,List of Tuples.

# %% [markdown]
# # To create a dataframe from dictionary

# %%
stud={"pid":[2001,2002,2003,2004,2005,2006],"roll":[1,2,3,4,5,6],"name":['A','B','C','D','E','F']}
df3=pd.DataFrame(stud)
df3
# Out:
#     pid  roll name
# 0  2001     1    A
# 1  2002     2    B
# 2  2003     3    C
# 3  2004     4    D
# 4  2005     5    E
# 5  2006     6    F

# %% [markdown]
# # To create a dataframe from list

# %%
student=[(2001,1,'A'),(2002,2,'B'),(2003,3,'C'),(2004,4,'D'),(2005,5,'E'),(2006,6,'F')]
df4=pd.DataFrame(student,columns=["pid","roll","name"])
df4
# Out:
#     pid  roll name
# 0  2001     1    A
# 1  2002     2    B
# 2  2003     3    C
# 3  2004     4    D
# 4  2005     5    E
# 5  2006     6    F

# %% [markdown]
# ### Write a Python program to implement any 5 operations on Data Frame.

# %%
df.head()
# Out:
#    RollNo    Name     PID
# 0       1   irfan  894534
# 1       2     raj  567843
# 2       3  adarsh  896523
# 3       4   divya  563490
# 4       5   jyoti  895312

# %%
df.tail()
# Out:
#    RollNo    Name     PID
# 1       2     raj  567843
# 2       3  adarsh  896523
# 3       4   divya  563490
# 4       5   jyoti  895312
# 5       6  satbir  786521

# %%
df.columns
# Out:
# Index(['RollNo', 'Name', 'PID'], dtype='object')

# %%
df['RollNo'].max()
# Out:
# 6

# %%
df['RollNo'].min()
# Out:
# 1

# %%
df.describe()
# Out:
#          RollNo            PID
# count  6.000000       6.000000
# mean   3.500000  767370.500000
# std    1.870829  161842.623927
# min    1.000000  563490.000000
# 25%    2.250000  622512.500000
# 50%    3.500000  840527.500000
# 75%    4.750000  895117.500000
# max    6.000000  896523.000000

# %%
df[df.RollNo<=3]
# Out:
#    RollNo    Name     PID
# 0       1   irfan  894534
# 1       2     raj  567843
# 2       3  adarsh  896523

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
dfr=df.sort_values('PID')
dfr
# Out:
#    RollNo    Name     PID
# 3       4   divya  563490
# 1       2     raj  567843
# 5       6  satbir  786521
# 0       1   irfan  894534
# 4       5   jyoti  895312
# 2       3  adarsh  896523

# %%
df1=df1.fillna(0)
df1
# Out:
#    Roll. No    Name     PID
# 0         1  irfan   894534
# 1         2     raj  567843
# 2         3  adarsh  896523
# 3         4   divya  563490
# 4         5   jyoti  895312
# 5         6  satbir  786521

# %%
df1=df1.dropna()
df1
# Out:
#    Roll. No    Name     PID
# 0         1  irfan   894534
# 1         2     raj  567843
# 2         3  adarsh  896523
# 3         4   divya  563490
# 4         5   jyoti  895312
# 5         6  satbir  786521
